# %% [markdown]
# ## WELFake
#
# | Dataset Name + Scaler Type                | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |-------------------------------------------|----------|-------------------|---------------|---------------|
# | WELFake Validation - **Standard Scaler**  | **0.9823**   | **0.9812**            | **0.9825**        | **0.9818**        |
# | WELFake Test - **Standard Scaler**        | **0.9822**   | **0.9803**            | **0.9820**        | **0.9811**        |
# | WELFake Validation - MinMax Scaler        | 0.9812   | 0.9796            | 0.9820        | 0.9807        |
# | WELFake Test - MinMax Scaler              | 0.9811   | 0.9785            | 0.9817        | 0.9800        |

# %% [markdown]
# ## Fakeddit
#
# | Dataset Name + Scaler Type                | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |-------------------------------------------|----------|-------------------|---------------|---------------|
# | Fakeddit Validation - **Standard Scaler** | **0.8768**   | **0.8754**            | **0.8744**        | **0.8749**        |
# | Fakeddit Test - **Standard Scaler**       | **0.8771**   | **0.8756**            | **0.8746**        | **0.8750**        |
# | Fakeddit Validation - MinMax Scaler       | 0.8764   | 0.8750            | 0.8742        | 0.8746        |
# | Fakeddit Test - MinMax Scaler             | 0.8769   | 0.8753            | 0.8745        | 0.8749        |

# %% [markdown]
# ## Constraint
#
# | Dataset Name + Scaler Type                | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |-------------------------------------------|----------|-------------------|---------------|---------------|
# | Constraint Validation - **Standard Scaler** | **0.9441**   | **0.9443**            | **0.9436**        | **0.9439**        |
# | Constraint Test - **MinMax Scaler**       | **0.9439**   | **0.9441**            | **0.9434**        | **0.9437**        |
# | Constraint Validation - MinMax Scaler     | 0.9436   | 0.9441            | 0.9430        | 0.9434        |
# | Constraint Test - Standard Scaler         | 0.9430   | 0.9431            | 0.9425        | 0.9428        |

# %% [markdown]
# ## PolitiFact
#
# | Dataset Name + Scaler Type                | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |-------------------------------------------|----------|-------------------|---------------|---------------|
# | PolitiFact Validation - **MinMax Scaler** | **0.8942**   | **0.8974**            | **0.9041**        | **0.8940**        |
# | PolitiFact Test - **Standard Scaler**     | **0.8968**   | **0.9006**            | **0.8985**        | **0.8968**        |
# | PolitiFact Validation - Standard Scaler   | 0.8846   | 0.8817            | 0.8851        | 0.8831        |
# | PolitiFact Test - MinMax Scaler           | 0.8889   | 0.8915            | 0.8903        | 0.8889        |

# %% [markdown]
# ## GossipCop
#
# | Dataset Name + Scaler Type                | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |-------------------------------------------|----------|-------------------|---------------|---------------|
# | GossipCop Validation - **MinMax Scaler**  | **0.8502**   | 0.8089            | **0.7419**        | **0.7663**        |
# | GossipCop Test - **MinMax Scaler**        | **0.8446**   | 0.7975            | **0.7436**        | **0.7643**        |
# | GossipCop Validation - Standard Scaler    | 0.8494   | **0.8103**            | 0.7368        | 0.7627        |
# | GossipCop Test - Standard Scaler          | 0.8443   | **0.8018**            | 0.7352        | 0.7591        |

# %% [markdown]
# ![image.png](attachment:6fcb3276-503c-45f6-9b04-0e0b590d776f.png)

# %% [markdown]
# GossipCop is particularly challenging; recall is so low on the minority (fake) class, which is a problem. It is a significant issue if many of the fake news samples are being classified as real news!

# %% [markdown]
# ## All-Four Combined
#
# | Dataset Name + Scaler Type                      | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |-------------------------------------------------|----------|-------------------|---------------|---------------|
# | All-Four Combined Validation - **Standard Scaler** | **0.9321**   | **0.9288**            | 0.9285        | **0.9286**        |
# | All-Four Combined Test - **Standard Scaler**       | **0.9323**   | **0.9270**            | **0.9268**        | **0.9269**        |
# | All-Four Combined Validation - MinMax Scaler   | 0.9309   | 0.9265            | **0.9287**        | 0.9276        |
# | All-Four Combined Test - MinMax Scaler         | 0.9315   | 0.9252            | 0.9274        | 0.9263        |

# %% [markdown]
# ## Best Results: Full-Scale Evaluation Scenario Table
#
# | Dataset Name + Scaler Type                                | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score | Best Scaler   |
# |-----------------------------------------------------------|----------|-------------------|---------------|---------------|---------------|
# | WELFake Validation - Standard Scaler                      | 0.9823   | 0.9812            | 0.9825        | 0.9818        | Standard Scaler |
# | WELFake Test - Standard Scaler                            | 0.9822   | 0.9803            | 0.9820        | 0.9811        | Standard Scaler |
# | Fakeddit Validation - Standard Scaler                     | 0.8768   | 0.8754            | 0.8744        | 0.8749        | Standard Scaler |
# | Fakeddit Test - Standard Scaler                           | 0.8771   | 0.8756            | 0.8746        | 0.8750        | Standard Scaler |
# | Constraint Validation - Standard Scaler                   | 0.9441   | 0.9443            | 0.9436        | 0.9439        | Standard Scaler |
# | Constraint Test - MinMax Scaler                           | 0.9439   | 0.9441            | 0.9434        | 0.9437        | MinMax Scaler  |
# | PolitiFact Validation - MinMax Scaler                     | 0.8942   | 0.8974            | 0.9041        | 0.8940        | MinMax Scaler  |
# | PolitiFact Test - Standard Scaler                         | 0.8968   | 0.9006            | 0.8985        | 0.8968        | Standard Scaler |
# | GossipCop Validation - MinMax Scaler                      | 0.8502   | 0.8089            | 0.7419        | 0.7663        | MinMax Scaler  |
# | GossipCop Test - MinMax Scaler                            | 0.8446   | 0.7975            | 0.7436        | 0.7643        | MinMax Scaler  |
# | All-Four Combined Validation - Standard Scaler            | 0.9321   | 0.9288            | 0.9285        | 0.9286        | Standard Scaler |
# | All-Four Combined Test - Standard Scaler                  | 0.9323   | 0.9270            | 0.9268        | 0.9269        | Standard Scaler |

# %% [markdown]
# ## Five-Shot: WELFake Target
#
# | Dataset Name + Scaler Type                          | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |-----------------------------------------------------|----------|-------------------|---------------|---------------|
# | Five-Shot WELFake Target Validation - **Standard Scaler** | **0.6079**   | **0.5936**            | **0.5918**        | **0.5923**        |
# | Five-Shot WELFake Target Test - **Standard Scaler**       | **0.5906**   | **0.5727**            | **0.5751**        | **0.5730**        |
# | Five-Shot WELFake Target Validation - MinMax Scaler   | 0.4626   | 0.5612            | 0.5277        | 0.4139        |
# | Five-Shot WELFake Target Test - MinMax Scaler         | 0.4281   | 0.5581            | 0.5240        | 0.3831        |

# %% [markdown]
# ## Five-Shot: Constraint Target
#
# | Dataset Name + Scaler Type                              | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |---------------------------------------------------------|----------|-------------------|---------------|---------------|
# | Five-Shot Constraint Target Validation - **MinMax Scaler**   | **0.4873**   | **0.4960**            | **0.4966**        | **0.4730**        |
# | Five-Shot Constraint Target Test - **MinMax Scaler**         | **0.4609**   | **0.4656**            | **0.4699**        | **0.4480**        |
# | Five-Shot Constraint Target Validation - Standard Scaler | 0.4586   | 0.4622            | 0.4690        | 0.4386        |
# | Five-Shot Constraint Target Test - Standard Scaler       | 0.4486   | 0.4508            | 0.4589        | 0.4304        |

# %% [markdown]
# ## Five-Shot: PolitiFact Target
#
# | Dataset Name + Scaler Type                              | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |---------------------------------------------------------|----------|-------------------|---------------|---------------|
# | Five-Shot PolitiFact Target Validation - **Standard Scaler** | **0.7019**   | **0.7083**            | **0.7109**        | **0.7017**        |
# | Five-Shot PolitiFact Target Test - **MinMax Scaler**         | **0.7143**   | **0.7147**            | **0.7130**        | **0.7131**        |
# | Five-Shot PolitiFact Target Validation - MinMax Scaler   | 0.7019   | 0.6982            | 0.6872        | 0.6893        |
# | Five-Shot PolitiFact Target Test - Standard Scaler       | 0.6905   | 0.6946            | 0.6924        | 0.6900        |

# %% [markdown]
# ## Five-Shot: GossipCop Target
#
# | Dataset Name + Scaler Type                              | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |---------------------------------------------------------|----------|-------------------|---------------|---------------|
# | Five-Shot GossipCop Target Validation - **MinMax Scaler**   | **0.4205**   | **0.5395**            | **0.5456**        | **0.4186**        |
# | Five-Shot GossipCop Target Test - **MinMax Scaler**         | **0.4361**   | **0.5407**            | **0.5486**        | **0.4327**        |
# | Five-Shot GossipCop Target Validation - Standard Scaler | 0.3848   | 0.5504            | 0.5484        | 0.3847        |
# | Five-Shot GossipCop Target Test - Standard Scaler       | 0.3979   | 0.5383            | 0.5401        | 0.3978        |

# %% [markdown]
# ## Best Results: Five-Shot Evaluation Scenario
#
# | Dataset Name + Scaler Type                                      | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score | Best Scaler   |
# |-----------------------------------------------------------------|----------|-------------------|---------------|---------------|---------------|
# | Five-Shot WELFake Target Validation - Standard Scaler           | 0.6079   | 0.5936            | 0.5918        | 0.5923        | Standard Scaler |
# | Five-Shot WELFake Target Test - Standard Scaler                 | 0.5906   | 0.5727            | 0.5751        | 0.5730        | Standard Scaler |
# | Five-Shot Constraint Target Validation - MinMax Scaler          | 0.4873   | 0.4960            | 0.4966        | 0.4730        | MinMax Scaler  |
# | Five-Shot Constraint Target Test - MinMax Scaler                | 0.4609   | 0.4656            | 0.4699        | 0.4480        | MinMax Scaler  |
# | Five-Shot PolitiFact Target Validation - Standard Scaler       | 0.7019   | 0.7083            | 0.7109        | 0.7017        | Standard Scaler |
# | Five-Shot PolitiFact Target Test - MinMax Scaler                | 0.7143   | 0.7147            | 0.7130        | 0.7131        | MinMax Scaler  |
# | Five-Shot GossipCop Target Validation - MinMax Scaler          | 0.4205   | 0.5395            | 0.5456        | 0.4186        | MinMax Scaler  |
# | Five-Shot GossipCop Target Test - MinMax Scaler                | 0.4361   | 0.5407            | 0.5486        | 0.4327        | MinMax Scaler  |

# %% [markdown]
# ## Zero-Shot: WELFake Target
#
# | Dataset Name + Scaler Type                          | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |-----------------------------------------------------|----------|-------------------|---------------|---------------|
# | Zero-Shot WELFake Target Validation - **MinMax Scaler**   | **0.5454**   | **0.5604**            | **0.5607**        | **0.5454**        |
# | Zero-Shot WELFake Target Test - **MinMax Scaler**         | **0.5251**   | **0.5578**            | **0.5578**        | **0.5251**        |
# | Zero-Shot WELFake Target Validation - Standard Scaler | 0.4267   | 0.5341            | 0.5056        | 0.3342        |
# | Zero-Shot WELFake Target Test - Standard Scaler       | 0.3909   | 0.5318            | 0.5042        | 0.3073        |

# %% [markdown]
# ## Zero-Shot: Constraint Target
#
# | Dataset Name + Scaler Type                              | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |---------------------------------------------------------|----------|-------------------|---------------|---------------|
# | Zero-Shot Constraint Target Validation - **MinMax Scaler**   | **0.5367**   | **0.5320**            | **0.5274**        | **0.5144**        |
# | Zero-Shot Constraint Target Test - **MinMax Scaler**         | **0.5226**   | **0.5150**            | **0.5127**        | **0.4981**        |
# | Zero-Shot Constraint Target Validation - Standard Scaler | 0.4586   | 0.4626            | 0.4673        | 0.4455        |
# | Zero-Shot Constraint Target Test - Standard Scaler       | 0.4538   | 0.4576            | 0.4619        | 0.4436        |

# %% [markdown]
# ## Zero-Shot: PolitiFact Target
#
# | Dataset Name + Scaler Type                              | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |---------------------------------------------------------|----------|-------------------|---------------|---------------|
# | Zero-Shot PolitiFact Target Validation - **MinMax Scaler**   | **0.7019**   | **0.6969**            | **0.6898**        | **0.6916**        |
# | Zero-Shot PolitiFact Target Test - **MinMax Scaler**         | **0.7143**   | **0.7147**            | **0.7130**        | **0.7131**        |
# | Zero-Shot PolitiFact Target Validation - Standard Scaler | 0.6635   | 0.6964            | 0.6243        | 0.6084        |
# | Zero-Shot PolitiFact Target Test - Standard Scaler       | 0.5952   | 0.6427            | 0.6037        | 0.5692        |

# %% [markdown]
# ## Zero-Shot: GossipCop Target
#
# | Dataset Name + Scaler Type                              | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score |
# |---------------------------------------------------------|----------|-------------------|---------------|---------------|
# | Zero-Shot GossipCop Target Validation - **Standard Scaler** | **0.4513**   | **0.5419**            | **0.5525**        | **0.4451**        |
# | Zero-Shot GossipCop Target Test - **Standard Scaler**   | **0.4670**   | **0.5391**            | **0.5505**        | **0.4575**
# | Zero-Shot GossipCop Target Validation - MinMax Scaler   | 0.4141   | 0.5363            | 0.5413        | 0.4125        |
# | Zero-Shot GossipCop Target Test - MinMax Scaler         | 0.4342   | 0.5369            | 0.5441        | 0.4306        |

# %% [markdown]
# ## Best Results: Zero-Shot Evaluation Scenario
#
# | Dataset Name + Scaler Type                                      | Accuracy | Precision (Macro) | Recall (Macro) | Macro F1-score | Best Scaler   |
# |-----------------------------------------------------------------|----------|-------------------|---------------|---------------|---------------|
# | Zero-Shot WELFake Target Validation - MinMax Scaler             | 0.5454   | 0.5604            | 0.5607        | 0.5454        | MinMax Scaler |
# | Zero-Shot WELFake Target Test - MinMax Scaler                   | 0.5251   | 0.5578            | 0.5578        | 0.5251        | MinMax Scaler |
# | Zero-Shot Constraint Target Validation - MinMax Scaler          | 0.5367   | 0.5320            | 0.5274        | 0.5144        | MinMax Scaler |
# | Zero-Shot Constraint Target Test - MinMax Scaler                | 0.5226   | 0.5150            | 0.5127        | 0.4981        | MinMax Scaler |
# | Zero-Shot PolitiFact Target Validation - MinMax Scaler         | 0.7019   | 0.6969            | 0.6898        | 0.6916        | MinMax Scaler |
# | Zero-Shot PolitiFact Target Test - MinMax Scaler                | 0.7143   | 0.7147            | 0.7130        | 0.7131        | MinMax Scaler |
# | Zero-Shot GossipCop Target Validation - Standard Scaler        | 0.4513   | 0.5419            | 0.5525        | 0.4451        | Standard Scaler |
# | Zero-Shot GossipCop Target Test - Standard Scaler              | 0.4670   | 0.5391            | 0.5505        | 0.4575        | Standard Scaler |
